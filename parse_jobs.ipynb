# %%
import pandas as pd
import numpy as np
import pygsheets
from datetime import date
import re

# %%
def find_requirements(string):
    if string:
        start = re.search("([rR]equire)|([Qq]ualifications)",string)
        start = start.start() if start else 0
        end = re.search("[bB]enefits",string)
        end  = end.start() if end else len(string)
        requirements_ls = string[start:end].split('\n')
        for i in requirements_ls:
            if len(i)<=5:
                requirements_ls.remove(i)
        return '$'.join(requirements_ls[1:])
    return ''

# %%
def calculate_date(string):
    for i in range(len(string)):
        res = int(string[i].split(' ')[0])
        unit = string[i].split(' ')[1]
        if unit == 'minutes' or unit =='minute':
            string[i] = res
        elif unit == 'hours' or unit =='hour':
            string[i] = res*60
        elif unit == 'days'or unit =='day':
            string[i] = res*60*24
        elif unit == 'weeks' or unit =='week':
            string[i] = res*60*24*7
        elif unit == 'months' or unit =='month':
            string[i] = res*60*24*30
        else:
            string[i] = res
    return string

# %%
def parse_df(path='jobs.csv'):
    jobs = pd.read_csv(path)
    jobs.drop(index=jobs.loc[jobs['already_applied'].isna()==False].index,inplace = True)
    # jobs.drop(index=jobs.loc[jobs['easy_apply'].isna()==False].index,inplace = True)
    jobs.drop(columns=['Unnamed: 0','already_applied','applicant_count'],inplace = True)
    
    #split columns
    jobs['location'] = jobs['company'].apply(lambda x:x.split('·')[1])
    jobs['applicants'] = jobs['company'].apply(lambda x:int(x.split('·')[2][:-10].replace(',','')))
    jobs['company'] = jobs['company'].apply(lambda x:x.split('·')[0])
    pattern = r"[0-9]+"
    jobs['posted_date'] = jobs['location'].apply(lambda x: x[re.search(pattern,x).start():])
    jobs['location'] = jobs['location'].apply(lambda x: x[:re.search(pattern,x).start()])
    
    jobs['requirements']=jobs['job_description'].apply(find_requirements)
    jobs.drop(columns=['job_description'],inplace=True)
    jobs.sort_values(by = 'posted_date', key = calculate_date, inplace=True)
    jobs = jobs[['job_title','linkedin_url','company','company_linkedin_url','location','posted_date','easy_apply','applicants','requirements','benefits']]
    return jobs

# %%
def upload_df(df,path = 'C:/Users/Muggl/Desktop/linkedin-jobs-392523-00de46c464a4.json'):
# Update the google spreadsheet 
    gc=pygsheets.authorize(service_account_file=path)
    sh = gc.open('daily_linkedin_jobs')
    try:
        sh.add_worksheet(f"{str(date.today())}")
        current_sheet = sh.worksheets()[-1]
    except:
        current_sheet=sh.worksheet_by_title(f"{str(date.today())}")
        current_sheet.clear()
    
    current_sheet.set_dataframe(df,(1,1))
    res = []
    for i in range(2,len(df)+2):
        command = "=SUBSTITUTE(" + f"I{i}" + ',"$"'+",CHAR(10))"
        res.append([command])
    current_sheet.update_value("K1", "requirements_listed")
    current_sheet.update_values(f"K2:K{len(df)+2}",res,parse = True)

# %%
def main():
    job_df = parse_df()
    upload_df(job_df)

# %%
job_df = parse_df()
upload_df(job_df)

# %%
job_df
# Out:
#                            job_title  \
# 10                  Python Developer
# 34                  Python Developer
# 20                  Python Developer
# 15                  Python Developer
# 64  Software Engineer, Python - 1001
# ..                               ...
# 9     AWS / Python Software Engineer
# 16                 Software Engineer
# 23        Software Engineer (Python)
# 49                  Python Developer
# 28                  Python Developer
#
#                                          linkedin_url  \
# 10  https://www.linkedin.com/jobs/view/3655678689/...
# 34  https://www.linkedin.com/jobs/view/3660895686/...
# 20  https://www.linkedin.com/jobs/view/3660899423/...
# 15  https://www.linkedin.com/jobs/view/3661135382/...
# 64  https://www.linkedin.com/jobs/view/3660869057/...
# ..                                                ...
# 9   https://www.linkedin.com/jobs/view/3632641637/...
# 16  https://www.linkedin.com/jobs/view/3620277367/...
# 23  https://www.linkedin.com/jobs/view/3594316824/...
# 49  https://www.linkedin.com/jobs/view/3582074435/...
# 28  https://www.linkedin.com/jobs/view/3598301556/...
#
#                           company  \
# 10      Flexon Technologies Inc.
# 34                         Jobot
# 20    Avenues International Inc.
# 15     Open Systems Technologies
# 64  Reinventing Geospatial (RGi)
# ..                            ...
# 9                         Videon
# 16                Obscurity Labs
# 23  Harmonia Holdings Group, LLC
# 49                     Synechron
# 28                  InvestorFlow
#
#                                  company_linkedin_url  \
# 10  https://www.linkedin.com/company/flexon-techno...
# 34            https://www.linkedin.com/company/jobot/
# 20       https://www.linkedin.com/company/avenuesinc/
# 15  https://www.linkedin.com/company/open-systems-...
# 64  https://www.linkedin.com/company/reinventing-g...
# ..                                                ...
# 9    https://www.linkedin.com/company/videon-central/
# 16    https://www.linkedin.com/company/obscuritylabs/
# 23  https://www.linkedin.com/company/harmonia-hold...
# 49        https://www.linkedin.com/company/synechron/
# 28     https://www.linkedin.com/company/investorflow/
#
#                               location     posted_date  easy_apply applicants  \
# 10           Cupertino, CA (On-site)      1 hour ago    Easy Apply          5
# 34           Rockville, MD (On-site)     3 hours ago    Easy Apply         19
# 20           Manhattan, NY (On-site)     3 hours ago    Easy Apply         32
# 15             New York, NY (Hybrid)     4 hours ago    Easy Apply         46
# 64             St Louis, MO (Hybrid)     6 hours ago         Apply          0
# ..                                 ...             ...         ...        ...
# 9             United States (Remote)     1 month ago         Apply        852
# 16           Chantilly, VA (On-site)     1 month ago           NaN        384
# 23      McLean, VA (Hybrid) Reposted     1 month ago           NaN        991
# 49   Charlotte, NC (Hybrid) Reposted    2 months ago    Easy Apply        386
# 28            United States (Remote)    2 months ago         Apply       1216
#
#                                          requirements  \
# 10  5+ years relevant job experience$Admin level e...
# 34  Create user-friendly and intuitive user interf...
# 20  Position Name: Senior Python Developer$Duratio...
# 15  A Bachelor's Degree in Computer Science, Engin...
# 64  Bachelor’s degree or equivalent experience$3+ ...
# ..                                                ...
# 9   Proficiency with serverless Cloud architecture...
# 16  Title: Software Engineer$Level: Intermediate S...
# 23  Essential Job Functions:$Knowledge and working...
# 49  An aspiring quant developer must learn a codin...
# 28  Collaborate with other developers to optimize ...
#
#                                              benefits
# 10                                                NaN
# 34  Pay found in job post\nRetrieved from the desc...
# 20  Employer-provided\nPay range in Manhattan, NY\...
# 15  Pay found in job post\nRetrieved from the desc...
# 64  Benefits found in job post\nDental insurance\n...
# ..                                                ...
# 9                                                 NaN
# 16  Employer-provided\nPay range in Chantilly, VA\...
# 23  Featured benefits\nDental insurance\nVision in...
# 49                                                NaN
# 28  Pay found in job post\nRetrieved from the desc...
#
# [73 rows x 10 columns]
